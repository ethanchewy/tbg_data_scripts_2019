# %%
import pandas as pd
import os

# %%
# read csv files as df

# Voting record of each county in California
df_ca_poli = pd.read_csv(r'C:\Users\ethan\OneDrive\Desktop\CA_U.SHouseofRepresentatives.csv', thousands=',')

# %%
print(df_ca_poli)
# Out:
#            county district name                      candidate party  votes  \
# 0    Districtwide    District 1                  Audrey Denney   DEM  18840
# 1    Districtwide    District 1         Jessica Jones Holcombe   DEM  12604
# 2    Districtwide    District 1                 David Peterson   DEM   3337
# 3    Districtwide    District 1                  Marty Walters   DEM   9296
# 4    Districtwide    District 1         Gregory Edward Cheadle   REP   6761
# 5    Districtwide    District 1                  Doug La Malfa   REP  55783
# 6    Districtwide    District 1                 Lewis Elbinger   GRN   1201
# 7           Butte    District 1                  Audrey Denney   DEM   9679
# 8           Butte    District 1         Jessica Jones Holcombe   DEM   4904
# 9           Butte    District 1                 David Peterson   DEM    795
# 10          Butte    District 1                  Marty Walters   DEM   2730
# 11          Butte    District 1         Gregory Edward Cheadle   REP   1637
# 12          Butte    District 1                  Doug La Malfa   REP  17004
# 13          Butte    District 1                 Lewis Elbinger   GRN    377
# 14          Glenn    District 1                  Audrey Denney   DEM     58
# 15          Glenn    District 1         Jessica Jones Holcombe   DEM     14
# 16          Glenn    District 1                 David Peterson   DEM      2
# 17          Glenn    District 1                  Marty Walters   DEM      6
# 18          Glenn    District 1         Gregory Edward Cheadle   REP     10
# 19          Glenn    District 1                  Doug La Malfa   REP    287
# 20          Glenn    District 1                 Lewis Elbinger   GRN      0
# 21         Lassen    District 1                  Audrey Denney   DEM    236
# 22         Lassen    District 1         Jessica Jones Holcombe   DEM    275
# 23         Lassen    District 1                 David Peterson   DEM     97
# 24         Lassen    District 1                  Marty Walters   DEM    160
# 25         Lassen    District 1         Gregory Edward Cheadle   REP    173
# 26         Lassen    District 1                  Doug La Malfa   REP   2128
# 27         Lassen    District 1                 Lewis Elbinger   GRN     16
# 28          Modoc    District 1                  Audrey Denney   DEM    343
# 29          Modoc    District 1         Jessica Jones Holcombe   DEM    113
# ..            ...           ...                            ...   ...    ...
# 709  Districtwide   District 51               Louis A. Fuentes   REP    820
# 710  Districtwide   District 51            Juan M. Hidalgo Jr.   REP   7277
# 711  Districtwide   District 51            John R. Renison Jr.   REP   7078
# 712  Districtwide   District 51  Juan Carlos "Charlie" Mercado   NPP   1387
# 713  Districtwide   District 51                 Kevin Mitchell   NPP    900
# 714      Imperial   District 51                    Juan Vargas   DEM   6219
# 715      Imperial   District 51               Louis A. Fuentes   REP    315
# 716      Imperial   District 51            Juan M. Hidalgo Jr.   REP   1850
# 717      Imperial   District 51            John R. Renison Jr.   REP   2065
# 718  U.S. House of Representatives    CA
# 719  U.S. House of Representatives    CA
# 720  U.S. House of Representatives    CA
# 721  U.S. House of Representatives    CA
# 722  U.S. House of Representatives    CA
# 723  U.S. House of Representatives    CA
# 724  U.S. House of Representatives    CA
# 725  U.S. House of Representatives    CA
# 726  U.S. House of Representatives    CA
# 727  U.S. House of Representatives    CA
# 728  U.S. House of Representatives    CA
# 729  U.S. House of Representatives    CA
# 730  U.S. House of Representatives    CA
# 731  U.S. House of Representatives    CA
# 732  U.S. House of Representatives    CA
# 733  U.S. House of Representatives    CA
# 734  U.S. House of Representatives    CA
# 735  U.S. House of Representatives    CA
# 736  U.S. House of Representatives    CA
# 737  U.S. House of Representatives    CA
# 738  U.S. House of Representatives    CA
#
# [739 rows x 7 columns]

# %%
# GOAL: Process County Level Data to Get Political affiliations of county

# Get Key Values and Set Up New Data Frame
ca_key_vals = df_ca_poli.county.unique()
df_ca_poli_clean = pd.DataFrame(columns=["County", "Republican", "Democrat", "Other"])
df_ca_poli_clean["County"] = ca_key_vals
# print(df_ca_poli_clean)

# Calculate percentage
find_affiliation_tot = lambda df, affil, p_value, v_value : df.loc[df[v_value] == affil][v_value].sum()
for county in ca_key_vals:
    county_df = df_ca_poli.loc[df_ca_poli["county"] == county]
    county_total_votes = county_df["votes"].sum()
    dem_votes = find_affiliation_tot(county_df, "DEM", "party", "votes")
    rep_votes = find_affiliation_tot(county_df, "REP", "party", "votes")
    other_votes = find_affiliation_tot(county_df, "NPP", "party", "votes")

    df_ca_poli_clean.loc[df_ca_poli_clean["County"] == county, ["Republican"]] = (rep_votes/county_total_votes)*100
    df_ca_poli_clean.loc[df_ca_poli_clean["County"] == county, ["Democrat"]] = (dem_votes/county_total_votes)*100
    df_ca_poli_clean.loc[df_ca_poli_clean["County"] == county, ["Other"]] = (other_votes/county_total_votes)*100

print(df_ca_poli_clean)

# Remove CountyWide
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-a2a80dc03c53> in <module>
#      12     county_df = df_ca_poli.loc[df_ca_poli["county"] == county]
#      13     county_total_votes = county_df["votes"].sum()
# ---> 14     dem_votes = find_affiliation_tot(county_df, "DEM", "party", "votes")
#      15     rep_votes = find_affiliation_tot(county_df, "REP", "party", "votes")
#      16     other_votes = find_affiliation_tot(county_df, "NPP", "party", "votes")
#
# <ipython-input-51-a2a80dc03c53> in <lambda>(df, affil, p_value, v_value)
#       8
#       9 # Calculate percentage
# ---> 10 find_affiliation_tot = lambda df, affil, p_value, v_value : df.loc[df[value] == affil][v_value].sum()
#      11 for county in ca_key_vals:
#      12     county_df = df_ca_poli.loc[df_ca_poli["county"] == county]
#
# NameError: name 'value' is not defined
